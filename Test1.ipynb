# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulRaheym/GitHubProject1/blob/main/Test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello, Dunia KSK!")
# Out:
# hello, Dunia KSK!

# %% [markdown]
# # New section

# %%
nama="Ahmad"
umur = 19
tahun_lahir = 2026 - umur
print("Nama saya", nama, "dan saya lahir pada tahun", tahun_lahir)
# Out:
# Nama saya Ahmad dan saya lahir pada tahun 2007

# %% [markdown]
# # New section
